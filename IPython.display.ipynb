# %%
from IPython.display import IFrame, YouTubeVideo, HTML

# %%
IFrame('https://matplotlib.org/2.0.2/examples/color/named_colors.html', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://matplotlib.org/2.0.2/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('https://www.mrta.co.th/media/894900/1mrta-recruitment-2020.pdf', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://www.mrta.co.th/media/894900/1mrta-recruitment-2020.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
s='''
<table class="table table-hover table-set col-3-center table-set-border-yellow">
                <thead>
                <tr>
                    <th></th>
                    <th><strong>ล่าสุด</strong></th>
                    <th><strong>เปลี่ยนแปลง</strong></th>
                    <th><strong>มูลค่า<br>(ลบ.)</strong></th>
                </tr>
                </thead>
                <tbody>
                
                    <tr>
                        <td>
                            
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH" target="_blank">SET</a>
                                
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                1,267.63
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-7.53</td>
                        <td style="text-align: right;">42,536.46</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&amp;language=th&amp;country=TH" target="_blank">SET50</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                808.83
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-6.98</td>
                        <td style="text-align: right;">22,659.26</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET100&amp;language=th&amp;country=TH" target="_blank">SET100</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                1,808.85
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-15.15</td>
                        <td style="text-align: right;">29,070.33</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=sSET&amp;language=th&amp;country=TH" target="_blank">sSET</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                607.41
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-2.31</td>
                        <td style="text-align: right;">1,716.26</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETCLMV&amp;language=th&amp;country=TH" target="_blank">SETCLMV</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                848.61
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-2.74</td>
                        <td style="text-align: right;">15,700.24</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETHD&amp;language=th&amp;country=TH" target="_blank">SETHD</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                826.99
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-14.87</td>
                        <td style="text-align: right;">11,554.09</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETTHSI&amp;language=th&amp;country=TH" target="_blank">SETTHSI</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                756.32
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-5.71</td>
                        <td style="text-align: right;">22,826.83</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETWB&amp;language=th&amp;country=TH" target="_blank">SETWB</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                871.68
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-3.35</td>
                        <td style="text-align: right;">8,708.06</td>
                    </tr>
                
                </tbody>
            </table>'''
HTML(s)
# Out:
# <table class="table table-hover table-set col-3-center table-set-border-yellow">
#                 <thead>
#                 <tr>
#                     <th></th>
#                     <th><strong>ล่าสุด</strong></th>
#                     <th><strong>เปลี่ยนแปลง</strong></th>
#                     <th><strong>มูลค่า<br>(ลบ.)</strong></th>
#                 </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr>
#                         <td>
#
#                                 <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH" target="_blank">SET</a>
#
#
#                         </td>
#
#
#
#
#
#
#
#
#
#                         <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
#
#
#                                 1,267.63
#
#
#                         </td>
#                         <td style="text-align: right;" class="set-color-red">-7.53</td>
# ...

# %%
q='''
<div class="panel">
<div class="kssb panel-heading bg-maroon-light-color f24">
อัตราดอกเบี้ยเงินฝาก
</div>

<table class="table"> 
 
    
<tbody><tr>
<td width="35%">ออมทรัพย์ </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.25%</td>
</tr><tr>
<td width="35%">กระแสรายวัน </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.00%</td>
</tr><tr>
<td width="35%">ประจำ 3 เดือน </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.375%</td>
</tr><tr>
<td width="35%">ประจำ 6 เดือน </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.50%</td>
</tr><tr>
<td width="35%">ประจำ 12 เดือน </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.50%</td>
</tr><tr>
<td width="35%">ประจำ 24 เดือน </td>
<td width="35%">ดอกเบี้ย/ปี</td>
<td width="20%" class="f-orange">0.50%</td>
</tr>

</tbody></table>

<div class="panel-footer ">
  <div class="col-sm-3 col-xs-5">
    <a href="/bank/Other/Interestratesfees/Depositinterestrate.aspx"> 
      + ดูทั้งหมด
    </a>
  </div>
  <div class="col-sm-9 col-xs-7"> 
    <style>
      .br_factsheet{display:none;}
      .link_factsheet{font-size: 14px;float: right;}
      @media(max-width:991px){
        .br_factsheet{display:block;}
      }
    </style>
    <a href="https://www.krungsri.com/bank/th/Other/Download-Forms/product-catalog-and-factsheet.html" class="link_factsheet" onclick="dataLayer.push({'event':'track_event','event_category':'mainpage_th','event_action':'click','event_label':'product_catalog_and_factsheet'});">+ ตารางเปิดเผยข้อมูล และข้อตกลงการใช้บริการเงินฝาก</a>
    <br class="br_factsheet">
  </div>
</div>


</div>'''
HTML(q)
# Out:
# <div class="panel">
# <div class="kssb panel-heading bg-maroon-light-color f24">
# อัตราดอกเบี้ยเงินฝาก
# </div>
#
# <table class="table">
#
#
# <tbody><tr>
# <td width="35%">ออมทรัพย์ </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.25%</td>
# </tr><tr>
# <td width="35%">กระแสรายวัน </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.00%</td>
# </tr><tr>
# <td width="35%">ประจำ 3 เดือน </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.375%</td>
# </tr><tr>
# <td width="35%">ประจำ 6 เดือน </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.50%</td>
# </tr><tr>
# <td width="35%">ประจำ 12 เดือน </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.50%</td>
# </tr><tr>
# <td width="35%">ประจำ 24 เดือน </td>
# <td width="35%">ดอกเบี้ย/ปี</td>
# <td width="20%" class="f-orange">0.50%</td>
# </tr>
#
# </tbody></table>
#
# <div class="panel-footer ">
# ...
